# %%
from modfilegen.Converter.CelsiusConverter import celsiusconverter
from modfilegen import GlobalVariables
import sqlite3
from pathlib import Path
import os

# %%
data = "/data"
modeldictionnary_f = os.path.join(data,"ModelsDictionaryArise.db")
masterinput_f =  os.path.join(data, "MasterInput.db")
celsius_f = os.path.join(data, "CelsiusV3nov17_dataArise.db")
ori_mi = os.path.join(data, "ori_MasterInput.db")


GlobalVariables["dbModelsDictionary" ] = modeldictionnary_f     
GlobalVariables["dbMasterInput" ] = masterinput_f 
GlobalVariables["directorypath"] = data   # contains the path of list of USM
GlobalVariables["nthreads"] = 1
GlobalVariables["dt"] = 0
GlobalVariables["ori_MI"] = ori_mi
GlobalVariables["dbCelsius"] = celsius_f

# check if modeldictionnary_f exists
if not Path(modeldictionnary_f).is_file():
    print(f"Error: {modeldictionnary_f} does not exist.")
else:    print(f"{modeldictionnary_f} found.")
# Out:
# /data/ModelsDictionaryArise.db found.

# %%
def test_celsiusconverter():
    celsiusconverter.main()
    return 0

if __name__ == "__main__":
    test_celsiusconverter()
    print("test_celsiusconverter")
# Out:
# 📊 Total simulations to process: 160
# Processing 1 chunks...
# Number of idsims 160
# creating new directory for process
# Copy SimulationList
# SimulationList copied
# Start transfert of climate data from MI to Cel
# Start transfert of climate data from MI to Cel
# Number of idPoints 40
# transfert of climate data from MI to Cel done
# copy CropManagement, Soil and SoilLayers
# convert celsius
# Start : 2026/06/10 00:55:54
# dbMasterInput : URI=file:db/MasterInput.db
# dbModelsDictionary : URI=file:db/ModelsDictionaryArise.db
# dbCelsius : URI=file:db/CelsiusV3nov17_dataArise.db
# n : 10
# cmd : convert
# models : celsius
# nthreads : 1
# dbMasterInput : URI=file:/data/proc_47f05112-438f-4b42-86c5-d2f81c5c3c90/MasterInput.db
# dbModelsDictionary : URI=file:/data/ModelsDictionaryArise.db
# dbCelsius : URI=file:/data/proc_47f05112-438f-4b42-86c5-d2f81c5c3c90/CelsiusV3nov17_dataArise.db
# sstart : 0
# send : -1
# CelsiusConverter...
# dbMasterInput : URI=file:/data/proc_47f05112-438f-4b42-86c5-d2f81c5c3c90/MasterInput.db
# dbCelsius : URI=file:/data/proc_47f05112-438f-4b42-86c5-d2f81c5c3c90/CelsiusV3nov17_dataArise.db
# ListPAnnexes
# SimuList
# End : 2026/06/10 00:55:54
# ✅ Celsius conversion completed successfully!
# run celsius
# Start : 2026/06/10 00:55:54
# dbCelsius ori : URI=file:/package/db/CelsiusV3nov17_dataArise.db
# n args : 6
# cmd 111 : convert
# models 1111 : celsius
# nthreads 1111 : 1
# dbCelsius : URI=file:/data/proc_47f05112-438f-4b42-86c5-d2f81c5c3c90/CelsiusV3nov17_dataArise.db
# sstart : 0
# send : -1
# NumSimul : 160
# 0/160
# 1/160
# 2/160
# -7.125_30.575_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 3/160
# -7.125_30.575_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 4/160
# 5/160
# 6/160
# -7.125_30.625_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 7/160
# -7.125_30.625_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 8/160
# 9/160
# 10/160
# -7.125_30.875_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 11/160
# -7.125_30.875_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 12/160
# 13/160
# 14/160
# -7.125_30.925_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 15/160
# -7.125_30.925_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 16/160
# 17/160
# 18/160
# -7.125_30.975_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 19/160
# -7.125_30.975_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 20/160
# 21/160
# 22/160
# -7.125_31.025_2012_MgtMais0_310_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
# 23/160
# -7.125_31.025_2012_MgtMais0_320_2Fin de simulation apres fin des données climatiques !!! Réduisez la période de simulation
#